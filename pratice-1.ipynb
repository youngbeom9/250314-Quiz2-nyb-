# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
act = pd.read_csv(r"C:\Users\302-28\Downloads\OTg6QzA_activities.csv")

# %%
X = act.X.to_numpy()
Y = act.Y.to_numpy()

# %%
fig=plt.figure(figsize=(18,12))

fig.add_subplot(2,2,1)
plt.hist2d(X[:16570], Y[:16570], bins=20, cmap='viridis')
plt.title('1-Q')
plt.colorbar()

fig.add_subplot(2,2,2)
plt.hist2d(X[16570:16570*2], Y[16570:16570*2], bins=20, cmap='gray')
plt.title('2-Q')
plt.colorbar()

fig.add_subplot(2,2,3)
plt.hist2d(X[16570*2:16570*3], Y[16570*2:16570*3], bins=20, cmap='magma')
plt.title('3-Q')
plt.colorbar()

fig.add_subplot(2,2,4)
plt.hist2d(X[16570*3:], Y[16570*3:], bins=20, cmap='magma')
plt.title('4-Q')
plt.colorbar()

plt.show()

# %%
fig=plt.figure(figsize=(18,12),facecolor='gray')

fig.add_subplot(2,2,1)
plt.scatter(X[:16570], Y[:16570],c='k')
plt.title('1-Q')

fig.add_subplot(2,2,2)
plt.scatter(X[16570:16570*2], Y[16570:16570*2],c='k')
plt.title('2-Q')

fig.add_subplot(2,2,3)
plt.scatter(X[16570*2:16570*3], Y[16570*2:16570*3],c='k')
plt.title('3-Q')

fig.add_subplot(2,2,4)
plt.scatter(X[16570*3:], Y[16570*3:],c='k')
plt.title('4-Q')

plt.show()

# %%
act.plot(kind='scatter',x='X',y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
act.plot(kind ='density',x='X',y='Y')
# Out:
# <Axes: ylabel='Density'>

# %%
kp=pd.read_csv(r"C:\Users\302-28\Downloads\kr_population.csv")

# %%
kp.head()
# Out:
#    Year  population   birth   death  increments  birthrate
# 0  1925    12997611  558897  359042      199855       6.59
# 1  1926    13052741  511667  337948      173719        NaN
# 2  1927    13037169  534524  353818      180706        NaN
# 3  1928    13105131  566142  357701      208441        NaN
# 4  1929    13124279  566969  414366      152603        NaN

# %%
plt.figure(figsize=(10, 6))
plt.plot(kp['Year'],kp['increments'],color='blue',alpha=0.7,label='Population Increase')

plt.title('Population Increase Over the Years in korea')
plt.xlabel('Year')
plt.ylabel('Population Increase')
plt.legend()
plt.grid()
plt.show()
